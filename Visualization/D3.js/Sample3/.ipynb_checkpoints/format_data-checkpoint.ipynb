# %%
import pandas as pd
df = pd.read_csv("FDI_Outflows.csv")
melted = pd.melt(df, id_vars=['Country'], var_name='year', value_name='FDI Outflows')
melted.to_csv("melted.csv", index=False)
melted.head()
# Out:
#             Country  year  FDI Outflows
# 0             Spain  1970            43
# 1           Austria  1970             9
# 2           Finland  1970            52
# 3           Denmark  1970            29
# 4         Australia  1970           112
# 5            Sweden  1970           213
# 6             Japan  1970           355
# 7            France  1970           374
# 8             Italy  1970           114
# 9            Canada  1970           931
# 10          Germany  1970          1070
# 11      Netherlands  1970          1317
# 12   United Kingdom  1970          1678
# 13    United States  1970          7590
# 14            Spain  1971            25
# 15          Austria  1971            36
# 16          Finland  1971            46
# 17          Denmark  1971            52
# 18        Australia  1971           104
# 19           Sweden  1971           176
# 20            Japan  1971           360
# 21           France  1971           397
# ...
